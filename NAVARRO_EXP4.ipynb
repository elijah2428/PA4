# %%
# Import the pandas library, used for data manipulation and analysis.
import pandas as pd
# Import the pyplot module from matplotlib for creating visualizations (e.g., plots, charts).
import matplotlib.pyplot as plt

# %%
# Load the Excel file 'board2.xlsx' into a DataFrame called 'board'
board = pd.read_excel('board2.xlsx')
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
# Filter the 'board' DataFrame for the following conditions:
# 1. 'Hometown' is 'Luzon'
# 2. 'Track' is 'Instrumentation'
# 3. 'Electronics' score is greater than 70
# Select only the 'Name', 'GEAS', and 'Electronics' columns from the rows that meet the conditions
instru = board.loc[(board['Hometown'] == 'Luzon')&
          (board['Track'] == 'Instrumentation')&
          (board['Electronics']>70), ['Name', 'GEAS', 'Electronics']]

# %%
instru
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 instru
#
# NameError: name 'instru' is not defined

# %%
#This calculates the row-wise average of the columns 'Math', 'Electronics', 'GEAS', and 'Communication'
board['Average'] = board[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1)
# Filter the 'board' DataFrame for the following conditions:
# 1. 'Hometown' is 'Mindanao'
# 2. 'Gender' is 'Female'
# 3. 'Average' score is greater than or equal to 55
# Select only the 'Name', 'Track', 'Electronics', and 'Average' columns from the rows that meet the conditions
mindy = board.loc[(board['Hometown'] == 'Mindanao')&
                  (board['Gender'] == 'Female')&
                  (board['Average']>=55), ['Name', 'Track', 'Electronics', 'Average']]

# %%
mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %%
plt.figure(figsize=(15, 10))

# 1. Boxplot for Average Grade by Track
# Removed plt.subplot and let boxplot handle the layout
board.boxplot(column='Average_Grade', by='Communication', grid=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
plt.title('Average Grade by Track')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xlabel('Track')
plt.ylabel('Average Grade')

# 2. Boxplot for Average Grade by Gender
plt.figure(figsize=(15, 10))  # Create a new figure for the next boxplot
board.boxplot(column='Average_Grade', by='Gender', grid=False, patch_artist=True, boxprops=dict(facecolor='lightgreen'))
plt.title('Average Grade by Gender')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xlabel('Gender')
plt.ylabel('Average Grade')

# 3. Boxplot for Average Grade by Hometown
plt.figure(figsize=(15, 10))  # Create a new figure for the next boxplot
board.boxplot(column='Average_Grade', by='Hometown', grid=False, patch_artist=True, boxprops=dict(facecolor='lightcoral'))
plt.title('Average Grade by Hometown')
plt.suptitle('')  # Remove the default title added by boxplot
plt.xlabel('Hometown')
plt.ylabel('Average Grade')

# Show the plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       1 plt.figure(figsize=(15, 10))
#       3 # 1. Boxplot for Average Grade by Track
#       4 # Removed plt.subplot and let boxplot handle the layout
# ----> 5 board.boxplot(column='Average_Grade', by='Communication', grid=False, patch_artist=True, boxprops=dict(facecolor='lightblue'))
#       6 plt.title('Average Grade by Track')
#       7 plt.suptitle('')  # Remove the default title added by boxplot
#
# File D:\anacondanavigator\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)
#     530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# ...
